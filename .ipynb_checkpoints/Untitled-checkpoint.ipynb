# %%
import requests
import pandas as pd
import time
import numpy as np

# %%
api_key = "92799143-1160-4401-8d10-24d2b387a2c2"
headers = {"Authorization": api_key}
start_date = "2025-10-20"
end_date = "2026-06-13"


games_list = []
cursor = None

while True:

    params = {
        "per_page": 100,
        "start_date": start_date,
        "end_date": end_date,
    }
    
    if cursor:
        params["cursor"] = cursor
    
    response = requests.get("https://api.balldontlie.io/v1/games", headers=headers, params=params)
    

    if response.status_code == 429:
        print("API limit hit. Wait 10 seconds...")
        time.sleep(10)
        continue
    
    data = response.json()
    games = data["data"]

    if not games:
        break
    
    for game in games:
        games_list.append(game)
    print(f"Found {len(games)} games (total: {len(games_list)})")
    

    cursor = data["meta"].get("next_cursor")
    

    if not cursor:
        break
    
        

print(f"\nTotal games found: {len(games_list)}")

if games_list:
    df = pd.DataFrame(games_list)
    print(f"Dataframe info: {df.shape}")
else:
    print("No games found")
    df = pd.DataFrame()
# Out:
# Found 100 games (total: 100)
# Found 100 games (total: 200)
# Found 100 games (total: 300)
# Found 100 games (total: 400)
# Found 100 games (total: 500)
# API limit hit. Wait 10 seconds...
# API limit hit. Wait 10 seconds...
# API limit hit. Wait 10 seconds...
# API limit hit. Wait 10 seconds...
# API limit hit. Wait 10 seconds...
# API limit hit. Wait 10 seconds...
# Found 100 games (total: 600)
# Found 100 games (total: 700)
# Found 100 games (total: 800)
# Found 100 games (total: 900)
# Found 100 games (total: 1000)
# API limit hit. Wait 10 seconds...
# API limit hit. Wait 10 seconds...
# API limit hit. Wait 10 seconds...
# API limit hit. Wait 10 seconds...
# API limit hit. Wait 10 seconds...
# API limit hit. Wait 10 seconds...
# Found 100 games (total: 1100)
# Found 100 games (total: 1200)
# Found 100 games (total: 1300)
# Found 22 games (total: 1322)
#
# Total games found: 1322
# Dataframe info: (1322, 32)

# %%
df["home_win"] = (df["home_team_score"] > df["visitor_team_score"])
df1 = df

# %%
df["home_win"] = (df["home_team_score"] > df["visitor_team_score"])
df1["home_name"] = df["home_team"].apply(lambda x:x["full_name"])
df1["visitor_name"] = df["visitor_team"].apply(lambda x:x["full_name"])

df1["home_abbrev"] = df["home_team"].apply(lambda x:x['abbreviation'])
df1["visitor_abbrev"] = df["visitor_team"].apply(lambda x:x['abbreviation'])
df1 = df.drop(["period", "time", "status", "postponed", "datetime", "home_q1", "home_q2", "home_q3", "home_q4", "home_ot1", "home_ot2", "home_ot3", "home_timeouts_remaining", "home_in_bonus", "visitor_q1", "visitor_q2", "visitor_q3", "visitor_q4", "visitor_ot1", "visitor_ot2", "visitor_ot3", "visitor_timeouts_remaining", "visitor_in_bonus", "home_team", "visitor_team", "ist_stage", "id", "date", "season",], axis=1)

df1["home_win"] = df["home_win"].astype(int)
# df ["postseason"] = df["postseason"].astype(int)
y = df["home_win"]

# df1 = df[df["postseason"]]
# df1["home_name"] = df["home_team"].apply(lambda x:x["full_name"])
# df1["visitor_name"] = df["visitor_team"].apply(lambda x:x["full_name"])

# df1["home_abbrev"] = df["home_team"].apply(lambda x:x['abbreviation'])
# df1["visitor_abbrev"] = df["visitor_team"].apply(lambda x:x['abbreviation'])
# df1 = df.drop(["period", "time", "status", "postponed", "datetime", "home_q1", "home_q2", "home_q3", "home_q4", "home_ot1", "home_ot2", "home_ot3", "home_timeouts_remaining", "home_in_bonus", "visitor_q1", "visitor_q2", "visitor_q3", "visitor_q4", "visitor_ot1", "visitor_ot2", "visitor_ot3", "visitor_timeouts_remaining", "visitor_in_bonus", "home_team", "visitor_team", "ist_stage", "id", "date", "season", "home_abbrev", "visitor_abbrev"], axis=1)
# df1["home_win"] = (df["home_team_score"] > df["visitor_team_score"])
# df1["home_win"] = df["home_win"].astype(int)

# %%
team_stats = {}
team_choose = "SAS"

for index, row in df1.iterrows():
    home = row["home_abbrev"]
    away = row["visitor_abbrev"]

    # print(df[df["postseason"][0]])

    if home not in team_stats:
        team_stats[home] = {"points": [], "points_allowed": [], "wins": []}
    team_stats[home]["points"].append(row["home_team_score"])
    team_stats[home]["points_allowed"].append(row["visitor_team_score"])
    team_stats[home]["wins"].append(row["home_win"])

    if away not in team_stats:
        team_stats[away] = {"points": [], "points_allowed": [], "wins": []}
    team_stats[away]["points"].append(row["visitor_team_score"])
    team_stats[away]["points_allowed"].append(row["home_team_score"])
    team_stats[away]["wins"].append(1-row["home_win"])

print()
# print(len(team_stats[team]["points_allowed"]))
# team_stats[team]["points"]
i = 0
avg_points = []
avg_points_allowed = []
avg_difference = []

for team in team_stats:
    i += 1
    # print(team, i, np.mean(team_stats[team]["points"]), np.mean(team_stats[team]["points_allowed"]), np.mean(team_stats[team]["points"])-np.mean(team_stats[team]["points_allowed"]))
    avg_points.append(float(np.mean(team_stats[team]["points"])))
    avg_points_allowed.append(float(np.mean(team_stats[team]["points_allowed"])))
    avg_difference.append(float(np.mean(team_stats[team]["points"])-np.mean(team_stats[team]["points_allowed"])))
    
df_team = df1[(df1["visitor_abbrev"] == team_choose) | (df1["home_abbrev"] == team_choose)]

# print(len(avg_points))
# print(len(avg_points_allowed))
# print(len(avg_difference))

team_game_count = {}

for team in team_stats:
    team_game_count[team] = 0

team_game_count

home_avg_points = []
home_avg_points_allowed = []
home_avg_difference = []
home_wins_percent = []
away_avg_points = []
away_avg_points_allowed = []
away_avg_points_difference = []
away_wins_percent = []
i = 0
for index, row in df_team.iterrows():
    home = row["home_abbrev"]
    away = row["visitor_abbrev"]
    
    home_num = team_game_count[home]
    away_num = team_game_count[away]
    i +=1
    # print(home_num, i)

    if home_num > 0:
        past_points = team_stats[home]["points"][:home_num]
        past_allowed_points = team_stats[home]["points_allowed"][:home_num]
        past_wins = team_stats[home]["wins"][:home_num]
        avg_points = sum(past_points)/home_num
        avg_points_allowed = sum(past_allowed_points)/home_num
        wins_percent = sum(past_wins)/home_num
        home_avg_points.append(avg_points)
        home_avg_points_allowed.append(avg_points_allowed)
        home_avg_difference.append(team_stats[home]["points"][0] - team_stats[home]["points_allowed"][0])
        home_wins_percent.append(wins_percent)
    else:
        home_avg_points.append(team_stats[home]["points"][0])
        home_avg_points_allowed.append(team_stats[home]["points_allowed"][0])
        home_wins_percent.append(team_stats[home]["wins"][0])
        home_avg_difference.append(avg_points-avg_points_allowed)

    if away_num > 0:
        past_points = team_stats[home]["points"][:away_num]
        past_allowed_points = team_stats[home]["points_allowed"][:away_num]
        past_wins = team_stats[home]["wins"][:away_num]
        avg_points = sum(past_points)/away_num
        avg_points_allowed = sum(past_allowed_points)/away_num
        wins_percent = sum(past_wins)/away_num
        away_avg_points.append(avg_points)
        away_avg_points_allowed.append(avg_points_allowed)
        away_avg_points_difference.append(avg_points-avg_points_allowed)
        away_wins_percent.append(wins_percent)
    else:
        away_avg_points.append(team_stats[away]["points"][0])
        away_avg_points_allowed.append(team_stats[away]["points_allowed"][0])
        away_wins_percent.append(team_stats[away]["wins"][0])
        away_avg_points_difference.append(avg_points-avg_points_allowed)

    team_game_count[home] += 1
    team_game_count[away] += 1

df_team["home_avg_points"] = home_avg_points
df_team["home_avg_points_allowed"] = home_avg_points_allowed
df_team["home_avg_difference"] = home_avg_difference
df_team["home_wins_percent"] = home_wins_percent
df_team["away_avg_points"] = away_avg_points
df_team["away_avg_points_allowed"] = away_avg_points_allowed
df_team["away_avg_difference"] = away_avg_points_difference
df_team["away_wins_percent"] = away_wins_percent

print("✅ Features added to DataFrame!")
print(df_team[["home_abbrev", "visitor_abbrev", "home_avg_points", "away_avg_points"]].head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 83
#      79     else:
#      80         home_avg_points.append(team_stats[home]["points"][0])
#      81         home_avg_points_allowed.append(team_stats[home]["points_allowed"][0])
#      82         home_wins_percent.append(team_stats[home]["wins"][0])
# ---> 83         home_avg_difference.append(avg_points-avg_points_allowed)
#      84
#      85     if away_num > 0:
#      86         past_points = team_stats[home]["points"][:away_num]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
len(home_avg_points)
# Out:
# 1322

# %%
away_avg_points
# Out:
# [125,
#  122.0,
#  117,
#  138,
#  121,
#  116.0,
#  117.5,
#  124,
#  125.0,
#  119.44444444444444,
#  119,
#  125.0,
#  116,
#  128,
#  118,
#  119.33333333333333,
#  121.125,
#  123.82352941176471,
#  118.83333333333333,
#  125.0,
#  119.25,
#  118.80952380952381,
#  112.5909090909091,
#  118.30434782608695,
#  123.04166666666667,
#  121.0,
#  120,
#  118.0,
#  112.57142857142857,
#  125.0,
#  121.93333333333334,
#  129,
#  125.0,
#  125.0,
#  110.05882352941177,
#  125.0,
#  115.69444444444444,
#  122.5,
#  117.15789473684211,
#  120.28205128205128,
#  121.4,
#  133,
#  122.5,
#  125.0,
#  116.72727272727273,
#  119.08888888888889,
#  121.0,
#  115.95744680851064,
#  116.20833333333333,
#  125.0,
#  121.0,
#  113.98039215686275,
#  122.5,
#  115.86792452830188,
#  115.57407407407408,
#  122.5,
#  125.0,
#  117.42105263157895,
#  113.74137931034483,
#  107.03389830508475,
#  117.21666666666667,
#  115.9672131147541,
#  125.0,
#  108,
#  121.0,
#  125.0,
#  125.0,
#  125.0,
#  113.45588235294117,
#  110.82608695652173,
#  121.0,
#  125.0,
#  120.18055555555556,
#  115.01369863013699,
#  110.43243243243244,
#  125.0,
#  114.86842105263158,
#  113.67532467532467,
#  121.56410256410257,
#  125.0,
#  122.5,
#  121.0,
#  121.0,
#  121.0,
#  121.0,
#  115.14117647058823,
#  115.05813953488372,
#  117.85714285714286,
#  121.0,
#  121.0,
#  117.18888888888888,
#  117.08791208791209,
#  117.85714285714286,
#  116.83870967741936,
#  118.85106382978724,
#  118.93684210526315,
#  117.85714285714286,
#  118.25,
#  117.27551020408163,
#  119.3,
#  114.93,
#  121.0,
#  121.0,
#  115.28155339805825,
#  114.17307692307692,
#  117.85714285714286]

# %%
team
# Out:
# 'DEN'
