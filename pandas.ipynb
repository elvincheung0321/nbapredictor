# %%
import pandas as pd

# %%
values= [10,20,30,40,50,60]

s = pd.Series(values,index=["a","b","c","d","a","a"])

s.loc["a"]

df = pd.DataFrame({
    "name":["Mike", "Bob", "Alice"],
    "job": ["Programmer", "Clerk", "Designer"],
    "age": [30, 80, 45]
}

df = df.set_index("name")

# %%
df
# Out:
#               job  age
# name
# Mike   Programmer   30
# Bob         Clerk   80
# Alice    Designer   45

# %%
df1 = pd.DataFrame({
    "a": [1,2,3]
}, index=[2,1,0])

df2 = pd.DataFrame({
    "a":[10,20,30]
}, index=[0,1,2])

df1+df2
# Out:
#     a
# 0  13
# 1  22
# 2  31

# %%
df = df.reset_index()

# %%
df
# Out:
#     name         job  age
# 0   Mike  Programmer   30
# 1    Bob       Clerk   80
# 2  Alice    Designer   45

# %%
df.to_csv("mydata.csv")

# %%
pd.read_csv("mydata.csv", index_col=0)
# Out:
#     name         job  age
# 0   Mike  Programmer   30
# 1    Bob       Clerk   80
# 2  Alice    Designer   45

# %%
from sklearn.datasets import fetch_california_housing

# %%
df = fetch_california_housing(as_frame=True).frame

# %%
list(df.columns)
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude',
#  'MedHouseVal']

# %%
pd.options.display.max_columns=500

df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
import matplotlib.pyplot as plt 
df["HouseAge"].hist()

plt.title("House Age")
plt.show()

df.hist(figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'MedInc'}>,
#         <Axes: title={'center': 'HouseAge'}>,
#         <Axes: title={'center': 'AveRooms'}>],
#        [<Axes: title={'center': 'AveBedrms'}>,
#         <Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'AveOccup'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>,
#         <Axes: title={'center': 'MedHouseVal'}>]], dtype=object)

# %%
import yfinance as yf

stock_df = yf.download("AAPL")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_df.hist ()
# Out:
# array([[<Axes: title={'center': "('Close', 'AAPL')"}>,
#         <Axes: title={'center': "('High', 'AAPL')"}>],
#        [<Axes: title={'center': "('Low', 'AAPL')"}>,
#         <Axes: title={'center': "('Open', 'AAPL')"}>],
#        [<Axes: title={'center': "('Volume', 'AAPL')"}>, <Axes: >]],
#       dtype=object)

# %%
df = pd.DataFrame({
    "name":["Mike","Alice","Bob"],
    "age": [30,45,80],
    "job": ["Programmer", "Designer", "Accountant"]
})

df = df.set_index("name")

# %%
df.loc["Alice","age"]
# Out:
# np.int64(45)

# %%
df.iloc[1]
# Out:
# age          45
# job    Designer
# Name: Alice, dtype: object

# %%
df.at["Alice","age"]
# Out:
# np.int64(45)

# %%
df.iat[1,0]
# Out:
# np.int64(45)

# %%
df.at["Alice","age"] = 60

# %%
df.loc["Alice"] = [75, "Clerk"]

# %%
df
# Out:
#        age         job
# name
# Mike    30  Programmer
# Alice   75       Clerk
# Bob     80  Accountant
# John    90     teacher

# %%
df.loc["John"] = [90, "teacher"]

# %%
df.iloc[:, 1]
# Out:
# name
# Mike     Programmer
# Alice         Clerk
# Bob      Accountant
# John        teacher
# Name: job, dtype: str

# %%
df.age = df.age *2

# %%
df.age
# Out:
# name
# Mike      60
# Alice    150
# Bob      160
# John     180
# Name: age, dtype: int64

# %%
def myfunction(x):
    if x % 3 == 0:
        return x**2
    else:
        return x//2

# %%
def myfunction2(x):
    if x.endswith("r"):
        return "no job"
    else:
        return x

# %%
df.age.apply(myfunction)
# Out:
# name
# Mike      3600
# Alice    22500
# Bob         80
# John     32400
# Name: age, dtype: int64

# %%
df.job = df.job.apply(myfunction2)

# %%
df
# Out:
#        age         job
# name
# Mike    60      no job
# Alice  150       Clerk
# Bob    160  Accountant
# John   180      no job

# %%
df.age.apply(lambda x: x**2 if x%10==0 else x//2)
# Out:
# name
# Mike      3600
# Alice    22500
# Bob      25600
# John     32400
# Name: age, dtype: int64

# %%
df["summary"] = df.apply(lambda row :f"Age: {row["age"]}, Job: {row["job"]}", axis = 1)

# %%
df.at["Alice","age"]=float("nan")

# %%
df.fillna(df.age.mean())
# Out:
#               age         job                    summary
# name
# Mike    60.000000      no job       Age: 60, Job: no job
# Alice  133.333333       Clerk       Age: 150, Job: Clerk
# Bob    160.000000  133.333333  Age: 160, Job: Accountant
# John   180.000000      no job      Age: 180, Job: no job

# %%
df.at["Bob","job"]= None

# %%
df[df.age.notna()]
# Out:
#         age     job                    summary
# name
# Mike   60.0  no job       Age: 60, Job: no job
# Bob   160.0     NaN  Age: 160, Job: Accountant
# John  180.0  no job      Age: 180, Job: no job

# %%
for i, col in df.items():
    print(col["Alice"])
# Out:
# nan
# Clerk
# Age: 150, Job: Clerk

# %%
df.age >50
# Out:
# name
# Mike      True
# Alice    False
# Bob       True
# John      True
# Name: age, dtype: bool

# %%
df[df.age>50]
# Out:
#         age     job                    summary
# name
# Mike   60.0  no job       Age: 60, Job: no job
# Bob   160.0     NaN  Age: 160, Job: Accountant
# John  180.0  no job      Age: 180, Job: no job

# %%
df[(df.age >50) | (df.job.notna())]
# Out:
#          age     job                    summary
# name
# Mike    60.0  no job       Age: 60, Job: no job
# Alice    NaN   Clerk       Age: 150, Job: Clerk
# Bob    160.0     NaN  Age: 160, Job: Accountant
# John   180.0  no job      Age: 180, Job: no job

# %%
df[-df.job.notna()]
# Out:
#         age  job                    summary
# name
# Bob   160.0  NaN  Age: 160, Job: Accountant

# %%
df = df.reset_index()

# %%
df
# Out:
#     name    age     job                    summary
# 0   Mike   60.0  no job       Age: 60, Job: no job
# 1  Alice    NaN   Clerk       Age: 150, Job: Clerk
# 2    Bob  160.0     NaN  Age: 160, Job: Accountant
# 3   John  180.0  no job      Age: 180, Job: no job

# %%
df[(df.name.str.endswith("e")) & (df.age>30)]
# Out:
#    name   age     job               summary
# 0  Mike  60.0  no job  Age: 60, Job: no job

# %%
df.age = df.age.fillna(30)

# %%
import datetime as dt
df["birthday"] = df["age"].apply(lambda x: dt.datetime.now()-dt.timedelta(days=365*x))

# %%
df.age = df.age.apply(lambda x: x/2 -10 if x>100 else x)

# %%
df[df.birthday.dt.year > 1950]
# Out:
#     name   age     job                    summary                   birthday
# 0   Mike  60.0  no job       Age: 60, Job: no job 1966-08-02 10:37:05.969223
# 1  Alice  30.0   Clerk       Age: 150, Job: Clerk 1996-07-25 10:37:05.969284
# 2    Bob  70.0     NaN  Age: 160, Job: Accountant 1956-08-04 10:37:05.969288

# %%
ages = [80]

df[df.age.isin(ages)]
# Out:
#    name   age     job                summary                   birthday
# 3  John  80.0  no job  Age: 180, Job: no job 1946-08-07 10:37:05.969291

# %%
df.query("age > 30")
# Out:
#    name   age     job                    summary                   birthday
# 0  Mike  60.0  no job       Age: 60, Job: no job 1966-08-02 10:37:05.969223
# 2   Bob  70.0     NaN  Age: 160, Job: Accountant 1956-08-04 10:37:05.969288
# 3  John  80.0  no job      Age: 180, Job: no job 1946-08-07 10:37:05.969291

# %%
df.job = df.job.fillna("Programmer")
df
# Out:
#     name   age         job                    summary  \
# 0   Mike  60.0      no job       Age: 60, Job: no job
# 1  Alice  30.0       Clerk       Age: 150, Job: Clerk
# 2    Bob  70.0  Programmre  Age: 160, Job: Accountant
# 3   John  80.0      no job      Age: 180, Job: no job
#
#                     birthday
# 0 1966-08-02 10:37:05.969223
# 1 1996-07-25 10:37:05.969284
# 2 1956-08-04 10:37:05.969288
# 3 1946-08-07 10:37:05.969291

# %%
df.groupby("job").agg({
    "age": "mean"
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[375], line 5
#       1 df.groupby("job").agg({
#       2     "age": "mean"
#       3 })
#       4
# ----> 5 df.drop(df["summary"])
#
# File ~/PersonalProjects/nbapredictor/venv/lib/python3.13/site-packages/pandas/core/frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File ~/PersonalProjects/nbapredictor/venv/lib/python3.13/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
# ...

# %%
df=df.drop("summary", axis=1)

df.loc[4]=["Jane", 35, "Programmer", None]

# %%
df
# Out:
#     name   age         job                    birthday
# 0   Mike  60.0      no job  1966-08-02 10:37:05.969223
# 1  Alice  30.0       Clerk  1996-07-25 10:37:05.969284
# 2    Bob  70.0  Programmre  1956-08-04 10:37:05.969288
# 3   John  80.0      no job  1946-08-07 10:37:05.969291
# 4   Jane  35.0  Programmer                        None

# %%
df.groupby("job").agg({
    "age": ["mean", "min", "max", "sum"]
})
# Out:
#              age
#             mean   min   max    sum
# job
# Clerk       30.0  30.0  30.0   30.0
# Programmer  52.5  35.0  70.0  105.0
# no job      70.0  60.0  80.0  140.0

# %%
df.sort_values("birthday", ascending=False)
# Out:
#     name   age         job                    birthday
# 1  Alice  30.0       Clerk  1996-07-25 10:37:05.969284
# 0   Mike  60.0      no job  1966-08-02 10:37:05.969223
# 2    Bob  70.0  Programmer  1956-08-04 10:37:05.969288
# 3   John  80.0      no job  1946-08-07 10:37:05.969291
# 4   Jane  35.0  Programmer                        None

# %%
df1 = pd.DataFrame({
    "Item": ["A", "B", "C"],
    "Price": [10, 20, 30]
})

df2 = pd.DataFrame({
    "Item": ["D", "E", "F"],
    "Price": [40, 50,60]
})

# %%
pd.concat([df1, df2]).reset_index().drop("index", axis=1)
# Out:
#   Item  Price
# 0    A     10
# 1    B     20
# 2    C     30
# 3    D     40
# 4    E     50
# 5    F     60

# %%
df1 = pd.DataFrame({
    "Item": ["A", "B", "C"],
    "Price": [10, 20, 30]
})

df2 = pd.DataFrame({
    "Country": ["X", "Y", "Z"],
    "Available": [True, True, False]
})

# %%
df1, df2
# Out:
# (  Item  Price
#  0    A     10
#  1    B     20
#  2    C     30,
#    Country  Available
#  0       X       True
#  1       Y       True
#  2       Z      False)

# %%
pd.concat([df1, df2], axis=1).reset_index().drop("index", axis=1)
# Out:
#   Item  Price Country  Available
# 0    A     10       X       True
# 1    B     20       Y       True
# 2    C     30       Z      False

# %%
df3 = pd.DataFrame({
    "Item": ["B", "C", "D"],
    "Country": ["X", "Y", "Z"]
})

df3
# Out:
#   Item Country
# 0    B       X
# 1    C       Y
# 2    D       Z

# %%
df1
# Out:
#   Item  Price
# 0    A     10
# 1    B     20
# 2    C     30

# %%
pd.merge(df1, df3, how="outer")
# Out:
#   Item  Price Country
# 0    A   10.0     NaN
# 1    B   20.0       X
# 2    C   30.0       Y
# 3    D    NaN       Z

# %%
df4 = pd.DataFrame({
    "Price": [10,20,30]
}, index=["A","B","C"])

df5 = pd.DataFrame({
    "Country": ["X","Y","Z"]
}, index=["B","C","D"])

# %%
df4.join(df5, how ="outer")
# Out:
#    Price Country
# A   10.0     NaN
# B   20.0       X
# C   30.0       Y
# D    NaN       Z

# %%
import requests
params = {
    "":
}
auth_token = "26af8e03-7266-4878-a6ce-6890a733f7d5"
headers = {"Authorization": auth_token}
response = requests.get("https://api.balldontlie.io/v1/games", headers=headers, params=params)
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[445], line 4
#       1 import requests
#       2 auth_token = "26af8e03-7266-4878-a6ce-6890a733f7d5"
#       3 headers = {"Authorization": auth_token}
# ----> 4 response = requests.get("https://api.balldontlie.io/v1/games", headers=headers, params=params)
#       5 data = response.json()
#
# NameError: name 'params' is not defined

# %%
from nba_api.stats.endpoints import leaguegamefinder

# Set your date (Format: YYYY-MM-DD)


# Find games from a specific date
gamefinder = leaguegamefinder.LeagueGameFinder(
    date_from_nullable=start_date,
    date_to_nullable=end_date
)

# The first DataFrame in the list contains the game information
games_df = gamefinder.get_data_frames()[0]
print(games_df)
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0      22023  1610612738               BOS         Boston Celtics  0022300563
# 1      22023  1610612741               CHI          Chicago Bulls  0022300561
# 2      22023  1610612752               NYK        New York Knicks  0022300557
# 3      22023  1610612762               UTA              Utah Jazz  0022300564
# 4      22023  1610612754               IND         Indiana Pacers  0022300564
# 5      22023  1610612760               OKC  Oklahoma City Thunder  0022300565
# 6      22023  1610612742               DAL       Dallas Mavericks  0022300556
# 7      22023  1610612764               WAS     Washington Wizards  0022300558
# 8      22023  1610612747               LAL     Los Angeles Lakers  0022300565
# 9      22023  1610612765               DET        Detroit Pistons  0022300558
# 10     22023  1610612745               HOU        Houston Rockets  0022300555
# ...

# %%
df1
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0      22025  1610612738               BOS          Boston Celtics
# 1      22025  1610612753               ORL           Orlando Magic
# 2      22025  1610612764               WAS      Washington Wizards
# 3      22025  1610612739               CLE     Cleveland Cavaliers
# 4      22025  1610612765               DET         Detroit Pistons
# 5      22025  1610612754               IND          Indiana Pacers
# 6      22025  1610612748               MIA              Miami Heat
# 7      22025  1610612737               ATL           Atlanta Hawks
# 8      22025  1610612766               CHA       Charlotte Hornets
# 9      22025  1610612752               NYK         New York Knicks
# 10     22025  1610612749               MIL         Milwaukee Bucks
# 11     22025  1610612755               PHI      Philadelphia 76ers
# 12     22025  1610612761               TOR         Toronto Raptors
# ...

# %%
start_date = "2026-04-12"
end_date = "2026-04-12"

game = leaguegamefinder.LeagueGameFinder(date_from_nullable=start_date, date_to_nullable=end_date)

df = game.get_data_frames()[0]
df2 = df.sort_values("GAME_ID").reset_index()

df1 = game.get_data_frames()[0].sort_values("GAME_ID").reset_index().drop("index", axis=1)

df1

# for index, row in df1.iterrows():
#     print(row["TEAM_ABBREVIATION"])
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0      22025  1610612738               BOS          Boston Celtics
# 1      22025  1610612753               ORL           Orlando Magic
# 2      22025  1610612764               WAS      Washington Wizards
# 3      22025  1610612739               CLE     Cleveland Cavaliers
# 4      22025  1610612765               DET         Detroit Pistons
# 5      22025  1610612754               IND          Indiana Pacers
# 6      22025  1610612748               MIA              Miami Heat
# 7      22025  1610612737               ATL           Atlanta Hawks
# 8      22025  1610612766               CHA       Charlotte Hornets
# 9      22025  1610612752               NYK         New York Knicks
# 10     22025  1610612749               MIL         Milwaukee Bucks
# 11     22025  1610612755               PHI      Philadelphia 76ers
# 12     22025  1610612761               TOR         Toronto Raptors
# ...

# %%
home_game = df1[df1["MATCHUP"].str.contains("@")].reset_index().drop("index", axis=1)
away_game = df1[-df1["MATCHUP"].str.contains("@")].reset_index().drop("index", axis=1)

# %%
home_game
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0      22025  1610612753               ORL          Orlando Magic  0022501186
# 1      22025  1610612764               WAS     Washington Wizards  0022501187
# 2      22025  1610612765               DET        Detroit Pistons  0022501188
# 3      22025  1610612737               ATL          Atlanta Hawks  0022501189
# 4      22025  1610612766               CHA      Charlotte Hornets  0022501190
# 5      22025  1610612749               MIL        Milwaukee Bucks  0022501191
# 6      22025  1610612751               BKN          Brooklyn Nets  0022501192
# 7      22025  1610612741               CHI          Chicago Bulls  0022501193
# 8      22025  1610612763               MEM      Memphis Grizzlies  0022501194
# 9      22025  1610612740               NOP   New Orleans Pelicans  0022501195
# 10     22025  1610612756               PHX           Phoenix Suns  0022501196
# ...

# %%
away_game
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0      22025  1610612738               BOS          Boston Celtics
# 1      22025  1610612739               CLE     Cleveland Cavaliers
# 2      22025  1610612754               IND          Indiana Pacers
# 3      22025  1610612748               MIA              Miami Heat
# 4      22025  1610612752               NYK         New York Knicks
# 5      22025  1610612755               PHI      Philadelphia 76ers
# 6      22025  1610612761               TOR         Toronto Raptors
# 7      22025  1610612742               DAL        Dallas Mavericks
# 8      22025  1610612745               HOU         Houston Rockets
# 9      22025  1610612750               MIN  Minnesota Timberwolves
# 10     22025  1610612760               OKC   Oklahoma City Thunder
# 11     22025  1610612759               SAS       San Antonio Spurs
# 12     22025  1610612747               LAL      Los Angeles Lakers
# ...

# %%
test = pd.merge(home_game, away_game, on=["GAME_ID", "GAME_DATE", "SEASON_ID"], suffixes=["_H","_A"])
test
# Out:
#    SEASON_ID   TEAM_ID_H TEAM_ABBREVIATION_H            TEAM_NAME_H  \
# 0      22025  1610612753                 ORL          Orlando Magic
# 1      22025  1610612764                 WAS     Washington Wizards
# 2      22025  1610612765                 DET        Detroit Pistons
# 3      22025  1610612737                 ATL          Atlanta Hawks
# 4      22025  1610612766                 CHA      Charlotte Hornets
# 5      22025  1610612749                 MIL        Milwaukee Bucks
# 6      22025  1610612751                 BKN          Brooklyn Nets
# 7      22025  1610612741                 CHI          Chicago Bulls
# 8      22025  1610612763                 MEM      Memphis Grizzlies
# 9      22025  1610612740                 NOP   New Orleans Pelicans
# 10     22025  1610612756                 PHX           Phoenix Suns
# 11     22025  1610612743                 DEN         Denver Nuggets
# 12     22025  1610612762                 UTA              Utah Jazz
# ...

# %%
test = pd.merge(home_game, away_game, on=["GAME_ID"], suffixes=["_H","_A"])
test
# Out:
#    SEASON_ID_H   TEAM_ID_H TEAM_ABBREVIATION_H            TEAM_NAME_H  \
# 0        22025  1610612753                 ORL          Orlando Magic
# 1        22025  1610612764                 WAS     Washington Wizards
# 2        22025  1610612765                 DET        Detroit Pistons
# 3        22025  1610612737                 ATL          Atlanta Hawks
# 4        22025  1610612766                 CHA      Charlotte Hornets
# 5        22025  1610612749                 MIL        Milwaukee Bucks
# 6        22025  1610612751                 BKN          Brooklyn Nets
# 7        22025  1610612741                 CHI          Chicago Bulls
# 8        22025  1610612763                 MEM      Memphis Grizzlies
# 9        22025  1610612740                 NOP   New Orleans Pelicans
# 10       22025  1610612756                 PHX           Phoenix Suns
# 11       22025  1610612743                 DEN         Denver Nuggets
# ...
